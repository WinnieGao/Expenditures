# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from scipy import stats
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn import metrics
import scipy
from sklearn import preprocessing

# %%
year4 = pd.read_csv("census_sf_msa_avg_1990_to_2015.csv")

# %%
year4.dropna(inplace = True)
year4log = year4.drop(year4.columns[[0, 1]], axis = 1)
year4log = np.log(year4log)
year4log["SFMSA.OWN"] = year4["SFMSA.OWN"]
year4log["SFMSA.DEGREE"] = year4["SFMSA.DEGREE"]
year4log["SFMSA.VEHICLES"] = year4["SFMSA.VEHICLES"]
year4log["YEAR"] = year4["YEAR"]

# %%
year4log
# Out:
#    SFMSA.AVGINCOME  SFMSA.SIZE  SFMSA.ROOMS  SFMSA.DEGREE  SFMSA.OWN  \
# 1        11.626235    0.943906     1.642873          0.52       0.54
# 3        11.488436    0.924259     1.644805          0.48       0.55
# 5        11.330845    0.959350     1.585145          0.39       0.55
# 7        11.165911    0.916291     1.611436          0.34       0.56
#
#    SFMSA.VEHICLES    YEAR
# 1            1.74  2015.0
# 3            1.70  2010.0
# 5            1.65  2000.0
# 7            1.75  1990.0

# %%
year15 = year4log[year4log["YEAR"] == 2015]
year15 = year15.drop(year15.columns[[6]], axis = 1)

# %%
year10 = year4log[year4log["YEAR"] == 2010]
year10 = year10.drop(year10.columns[[6]], axis = 1)

# %%
year00 = year4log[year4log["YEAR"] == 2000]
year00 = year00.drop(year00.columns[[6]], axis = 1)

# %%
year90 = year4log[year4log["YEAR"] == 1990]
year90 = year90.drop(year90.columns[[6]], axis = 1)

# %% [markdown]
# ##### 2015

# %%
fmli = pd.read_csv("fmli_15_clean_3.csv")

# %%
fmli = fmli[(fmli["PSU"] == "S49B")]

# %%
fmli.drop(["PSU"], axis = 1, inplace = True)

# %%
log = np.log(fmli)
log["OWN"] = fmli["OWN"]
log["DEGREE"] = fmli["DEGREE"]
log["VEHICLES"] = fmli["VEHICLES"]
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
sf2015msa = pd.read_csv("census_sf_msa_2015_cleaned.csv")
sf2015 = pd.read_csv("census.tracts.sf.2015.cleaned.csv")

# %%
dm1 = sf2015[["CT.SIZE", "CT.AVGINCOME", "CT.ROOMS", "CT.OWN", "CT.DEGREE", "CT.VEHICLES"]]
dm2 = sf2015msa[["SFMSA.SIZE", "SFMSA.AVGINCOME", "SFMSA.ROOMS", "SFMSA.OWN", "SFMSA.DEGREE", "SFMSA.VEHICLES"]]

# %%
log = np.log(fmli)
log["OWN"] = fmli["OWN"]
log["DEGREE"] = fmli["DEGREE"]
log["VEHICLES"] = fmli["VEHICLES"]
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
log_dm1 = np.log(dm1)
log_dm1["CT.OWN"] = dm1["CT.OWN"]
log_dm1["CT.DEGREE"] = dm1["CT.DEGREE"]
log_dm1["CT.VEHICLES"] = dm1["CT.VEHICLES"]
log_dm1["CT.Geo_GEOID"] = sf2015["CT.Geo_GEOID"]
log_dm1["CT.Geo_NAME"] = sf2015["CT.Geo_NAME"]
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
log_dm2 = np.log(dm2)
log_dm2["SFMSA.OWN"] = dm2["SFMSA.OWN"]
log_dm2["SFMSA.DEGREE"] = dm2["SFMSA.DEGREE"]
log_dm2["SFMSA.VEHICLES"] = dm2["SFMSA.VEHICLES"]
log_dm2["SFMSA.Geo_GEOID"] = sf2015msa["SFMSA.Geo_GEOID"]
log_dm2["SFMSA.Geo_NAME"] = sf2015msa["SFMSA.Geo_NAME"]

# %%
pred_dm1 = pd.DataFrame()

for i in range(17, len(log.columns)):
    df = log[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES", log.columns[i]]]
    df.replace(np.Inf, np.nan, inplace = True)
    df.replace(-np.Inf, np.nan, inplace = True)
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    X = df[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES"]]
    Y = df[log.columns[i]]
    X1 = sm.add_constant(X)
    model = linear_model.Lasso(alpha=0.03).fit(X1, Y)
    log_dm1.replace(np.Inf, np.nan, inplace = True)
    log_dm1.replace(-np.Inf, np.nan, inplace = True)
    log_dm1.dropna(inplace = True)
    Xp = log_dm1[["CT.SIZE", "CT.AVGINCOME", "CT.ROOMS", "CT.OWN", "CT.DEGREE", "CT.VEHICLES"]]
    Xp1 = sm.add_constant(Xp)
    pred_dm1[log.columns[i]] = np.array(model.predict(Xp1))
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# ...

# %%
result1 = pred_dm1
for i in pred_dm1.columns:
    result1[i] = np.exp(pred_dm1[i])

# %%
result1["CT.Geo_GEOID"] = log_dm1["CT.Geo_GEOID"]
result1["CT.Geo_NAME"] = log_dm1["CT.Geo_NAME"]

# %%
cols = list(result1.columns)
cols = [cols[len(cols) - 2]] + [cols[len(cols) - 1]] + cols[:len(cols) - 2]
result1 = result1[cols]

# %%
result1.head()
# Out:
#          CT.Geo_GEOID                                        CT.Geo_NAME  \
# 0  14000US06075010100  Census Tract 101, San Francisco County, Califo...
# 1  14000US06075010200  Census Tract 102, San Francisco County, Califo...
# 2  14000US06075010300  Census Tract 103, San Francisco County, Califo...
# 3  14000US06075010400  Census Tract 104, San Francisco County, Califo...
# 4  14000US06075010500  Census Tract 105, San Francisco County, Califo...
#
#    TotalExpenditures    TotalFood   FoodAtHome  FoodAwayFromHome  \
# 0       29326.432368  4690.187731  2770.242391       1979.646217
# 1       38367.467136  5247.448989  2920.505145       2247.935611
# 2       37563.461629  5483.916231  3155.373584       2283.555404
# 3       37077.628778  5262.237407  2980.591075       2242.980662
# 4       31263.932524  4634.597395  2626.622119       2040.626905
#
#    AlcoholicBeverages  Cerealsandbakeryproducts  Meatspoultryfishandeggs  \
# ...

# %%
result1.to_csv("pred_fmli_sf2015.csv")

# %%
pred_dm2 = pd.DataFrame()
pred_year15 = pd.DataFrame()

for i in range(17, len(log.columns)):
    df = log[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES", log.columns[i]]]
    df.replace(np.Inf, np.nan, inplace = True)
    df.replace(-np.Inf, np.nan, inplace = True)
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    X = df[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES"]]
    Y = df[log.columns[i]]
    X1 = sm.add_constant(X)
    model = linear_model.Lasso(alpha=0.03).fit(X1, Y)
    log_dm2.replace(np.Inf, np.nan, inplace = True)
    log_dm2.replace(-np.Inf, np.nan, inplace = True)
    log_dm2.dropna(inplace = True)
    Xp = log_dm2[["SFMSA.SIZE", "SFMSA.AVGINCOME", "SFMSA.ROOMS", "SFMSA.OWN", "SFMSA.DEGREE", "SFMSA.VEHICLES"]]
    Xp1 = sm.add_constant(Xp)
    pred_dm2[log.columns[i]] = np.array(model.predict(Xp1))
    year15["const"] = 1
    year15X = year15[["const", "SFMSA.SIZE", "SFMSA.AVGINCOME", "SFMSA.ROOMS", "SFMSA.OWN", "SFMSA.DEGREE", "SFMSA.VEHICLES"]]
    pred_year15[log.columns[i]] = np.array(model.predict(year15X))
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# ...

# %%
result2 = pred_dm2
for i in pred_dm2.columns:
    result2[i] = np.exp(pred_dm2[i])

# %%
result2["SFMSA.Geo_GEOID"] = log_dm2["SFMSA.Geo_GEOID"]
result2["SFMSA.Geo_NAME"] = log_dm2["SFMSA.Geo_NAME"]

# %%
cols = list(result2.columns)
cols = [cols[len(cols) - 2]] + [cols[len(cols) - 1]] + cols[:len(cols) - 2]
result2 = result2[cols]

# %%
result2.head()
# Out:
#   SFMSA.Geo_GEOID                    SFMSA.Geo_NAME  TotalExpenditures  \
# 0    05000US06001        Alameda County, California       40210.764112
# 1    05000US06013   Contra Costa County, California       43288.682593
# 2    05000US06041          Marin County, California       44971.663360
# 3    05000US06075  San Francisco County, California       36007.943818
# 4    05000US06081      San Mateo County, California       44679.337983
#
#      TotalFood   FoodAtHome  FoodAwayFromHome  AlcoholicBeverages  \
# 0  6088.166436  3774.333328       2227.477427          352.444329
# 1  6408.389505  3970.877829       2289.941072          384.909364
# 2  6208.798268  3670.487092       2347.428063          440.433871
# 3  5470.343432  3253.026457       2193.430851          365.150211
# 4  6405.909500  3872.782271       2379.754586          398.396233
#
#    Cerealsandbakeryproducts  Meatspoultryfishandeggs  Dairyproducts  ...  \
# ...

# %%
result2.to_csv("pred_fmli_sfmsa2015.csv")

# %%
for i in pred_year15:
    pred_year15[i] = np.exp(pred_year15[i])

# %% [markdown]
# ##### 2010

# %%
fmli = pd.read_csv("fmli_2010_clean_3.csv")

# %%
fmli = fmli[(fmli["PSU"] == 1422)]

# %%
fmli.drop(["PSU"], axis = 1, inplace = True)

# %%
log = np.log(fmli)
log["OWN"] = fmli["OWN"]
log["DEGREE"] = fmli["DEGREE"]
log["VEHICLES"] = fmli["VEHICLES"]
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %%
sf2010msa = pd.read_csv("census_sf_msa_cleaned_2010.csv")
sf2010 = pd.read_csv("census.tracts.sf.2010.cleaned.csv")

# %%
dm1 = sf2010[["CT2010.SIZE", "CT2010.AVGINCOME", "CT2010.ROOMS", "CT2010.OWN", "CT2010.DEGREE", "CT2010.VEHICLES"]]
dm2 = sf2010msa[["SFMSA.2010.SIZE", "SFMSA.2010.AVGINCOME", "SFMSA.2010.ROOMS", "SFMSA.2010.OWN", "SFMSA.2010.DEGREE", "SFMSA.2010.VEHICLES"]]

# %%
log = np.log(fmli)
log["OWN"] = fmli["OWN"]
log["DEGREE"] = fmli["DEGREE"]
log["VEHICLES"] = fmli["VEHICLES"]
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %%
log_dm1 = np.log(dm1)
log_dm1["CT2010.OWN"] = dm1["CT2010.OWN"]
log_dm1["CT2010.DEGREE"] = dm1["CT2010.DEGREE"]
log_dm1["CT2010.VEHICLES"] = dm1["CT2010.VEHICLES"]
log_dm1["CT2010.Geo_GEOID"] = sf2010["CT2010.Geo_GEOID"]
log_dm1["CT2010.Geo_NAME"] = sf2010["CT2010.Geo_NAME"]
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
log_dm2 = np.log(dm2)
log_dm2["SFMSA.2010.OWN"] = dm2["SFMSA.2010.OWN"]
log_dm2["SFMSA.2010.DEGREE"] = dm2["SFMSA.2010.DEGREE"]
log_dm2["SFMSA.2010.VEHICLES"] = dm2["SFMSA.2010.VEHICLES"]
log_dm2["SFMSA.2010.Geo_GEOID"] = sf2010msa["SFMSA.2010.Geo_GEOID"]
log_dm2["SFMSA.2010.Geo_NAME"] = sf2010msa["SFMSA.2010.Geo_NAME"]

# %%
pred_dm1 = pd.DataFrame()

for i in range(17, len(log.columns)):
    df = log[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES", log.columns[i]]]
    df.replace(np.Inf, np.nan, inplace = True)
    df.replace(-np.Inf, np.nan, inplace = True)
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    X = df[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES"]]
    Y = df[log.columns[i]]
    X1 = sm.add_constant(X)
    model = linear_model.Lasso(alpha=0.03).fit(X1, Y)
    log_dm1.replace(np.Inf, np.nan, inplace = True)
    log_dm1.replace(-np.Inf, np.nan, inplace = True)
    log_dm1.dropna(inplace = True)
    Xp = log_dm1[["CT2010.SIZE", "CT2010.AVGINCOME", "CT2010.ROOMS", "CT2010.OWN", "CT2010.DEGREE", "CT2010.VEHICLES"]]
    Xp1 = sm.add_constant(Xp)
    pred_dm1[log.columns[i]] = np.array(model.predict(Xp1))
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# ...

# %%
result1 = pred_dm1
for i in pred_dm1.columns:
    result1[i] = np.exp(pred_dm1[i])

# %%
result1["CT2010.Geo_GEOID"] = log_dm1["CT2010.Geo_GEOID"]
result1["CT2010.Geo_NAME"] = log_dm1["CT2010.Geo_NAME"]

# %%
cols = list(result1.columns)
cols = [cols[len(cols) - 2]] + [cols[len(cols) - 1]] + cols[:len(cols) - 2]
result1 = result1[cols]

# %%
result1.head()
# Out:
#      CT2010.Geo_GEOID                                    CT2010.Geo_NAME  \
# 0  14000US06075010100  Census Tract 101, San Francisco County, Califo...
# 1  14000US06075010200  Census Tract 102, San Francisco County, Califo...
# 2  14000US06075010300  Census Tract 103, San Francisco County, Califo...
# 3  14000US06075010400  Census Tract 104, San Francisco County, Califo...
# 4  14000US06075010500  Census Tract 105, San Francisco County, Califo...
#
#    TotalExpenditures    TotalFood   FoodAtHome  FoodAwayFromHome  \
# 0       22153.436069  3438.093462  2233.922589       1230.656349
# 1       29025.114869  3860.425063  2372.737515       1439.125780
# 2       26262.714129  3939.195590  2611.479476       1355.358670
# 3       27337.885609  3887.447103  2497.879965       1385.576791
# 4       27232.876548  3808.997042  2380.099697       1417.726140
#
#    AlcoholicBeverages   Cerealsandbakeryproducts    Meatspoultryfishandeggs   \
# ...

# %%
result1.to_csv("pred_fmli_sf2010.csv")

# %%
pred_dm2 = pd.DataFrame()
pred_year10 = pd.DataFrame()

for i in range(17, len(log.columns)):
    df = log[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES", log.columns[i]]]
    df.replace(np.Inf, np.nan, inplace = True)
    df.replace(-np.Inf, np.nan, inplace = True)
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    X = df[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES"]]
    Y = df[log.columns[i]]
    X1 = sm.add_constant(X)
    model = linear_model.Lasso(alpha=0.03).fit(X1, Y)
    log_dm2.replace(np.Inf, np.nan, inplace = True)
    log_dm2.replace(-np.Inf, np.nan, inplace = True)
    log_dm2.dropna(inplace = True)
    Xp = log_dm2[["SFMSA.2010.SIZE", "SFMSA.2010.AVGINCOME", "SFMSA.2010.ROOMS", "SFMSA.2010.OWN", "SFMSA.2010.DEGREE", "SFMSA.2010.VEHICLES"]]
    Xp1 = sm.add_constant(Xp)
    pred_dm2[log.columns[i]] = np.array(model.predict(Xp1))
    year10["const"] = 1
    year10X = year10[["const", "SFMSA.SIZE", "SFMSA.AVGINCOME", "SFMSA.ROOMS", "SFMSA.OWN", "SFMSA.DEGREE", "SFMSA.VEHICLES"]]
    pred_year10[log.columns[i]] = np.array(model.predict(year10X))
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# ...

# %%
result2 = pred_dm2
for i in pred_dm2.columns:
    result2[i] = np.exp(pred_dm2[i])

# %%
result2["SFMSA.2010.Geo_GEOID"] = log_dm2["SFMSA.2010.Geo_GEOID"]
result2["SFMSA.2010.Geo_NAME"] = log_dm2["SFMSA.2010.Geo_NAME"]

# %%
cols = list(result2.columns)
cols = [cols[len(cols) - 2]] + [cols[len(cols) - 1]] + cols[:len(cols) - 2]
result2 = result2[cols]

# %%
result2.head()
# Out:
#   SFMSA.2010.Geo_GEOID               SFMSA.2010.Geo_NAME  TotalExpenditures  \
# 0         05000US06001        Alameda County, California       29471.940869
# 1         05000US06013   Contra Costa County, California       31683.293122
# 2         05000US06041          Marin County, California       33324.646598
# 3         05000US06075  San Francisco County, California       26739.405081
# 4         05000US06081      San Mateo County, California       32090.654040
#
#      TotalFood   FoodAtHome  FoodAwayFromHome  AlcoholicBeverages  \
# 0  4298.360775  2913.967529       1393.574147          325.208130
# 1  4461.749962  3016.049771       1436.394862          335.167506
# 2  4447.632917  2895.953596       1499.117586          347.039859
# 3  3982.305744  2653.106100       1353.724812          315.944645
# 4  4511.713219  3014.729538       1479.834542          334.723578
#
#     Cerealsandbakeryproducts    Meatspoultryfishandeggs    Dairyproducts   \
# ...

# %%
result2.to_csv("pred_fmli_sfmsa2010.csv")

# %%
for i in pred_year10:
    pred_year10[i] = np.exp(pred_year10[i])

# %% [markdown]
# ##### 2000

# %%
fmli = pd.read_csv("fmli_2000_clean_3.csv")

# %%
fmli.columns
# Out:
# Index(['NEWID', 'AGE', 'DETTACHED', 'OWN', 'DEGREE', 'HHSIZE', 'INCOME',
#        'WEIGHT', 'WHITE', 'NORTHEAST', 'MIDWEST', 'SOUTH', 'WEST', 'ROOMS',
#        'STATE', 'PSU', 'MSA', 'VEHICLES', 'TotalExpenditures', 'TotalFood',
#        'FoodAtHome', 'FoodAwayFromHome', 'AlcoholicBeverages',
#        'Cerealsandbakeryproducts', 'Meatspoultryfishandeggs', 'Dairyproducts',
#        'Fruitsandvegetables', 'Otherfoodathome', 'Housing', 'Shelter',
#        'OtherLodging', 'UtilitiesFuelsAndPublicServices',
#        'HouseholdOperations', 'Housekeepingsupplies',
#        'HouseFurnishingsAndEquipment', 'HouseholdTextiles', 'Furniture',
#        'FloorCoverings', 'MajorAppliances', 'SmallAppliancesMiscHousewares',
#        'MiscHoushouseholdEquipment', 'ApparelAndServices', 'Transportation',
#        'VehiclePurchasesNetOutlay', 'Gasolineotherfuelsandmotoroil',
#        'Othervehicleexpenses', 'PublicAndOtherTransportation',
#        'PublicAndOtherTransportationOnTrips',
# ...

# %%
log = np.log(fmli)
log["OWN"] = fmli["OWN"]
log["DEGREE"] = fmli["DEGREE"]
log["VEHICLES"] = fmli["VEHICLES"]
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %%
sf2000msa = pd.read_csv("census_sf_msa_cleaned_2000.csv")
sf2000 = pd.read_csv("census-tracts.sf.cleaned_2000.csv")

# %%
dm1 = sf2000[["CT2000.SIZE", "CT2000.AVGINCOME", "CT2000.ROOMS", "CT2000.OWN", "CT2000.DEGREE", "CT2000.VEHICLES"]]
dm2 = sf2000msa[["SFMSA.2000.SIZE", "SFMSA.2000.AVGINCOME", "SFMSA.2000.ROOMS", "SFMSA.2000.OWN", "SFMSA.2000.DEGREE", "SFMSA.2000.VEHICLES"]]

# %%
log = np.log(fmli)
log["OWN"] = fmli["OWN"]
log["DEGREE"] = fmli["DEGREE"]
log["VEHICLES"] = fmli["VEHICLES"]
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %%
log_dm1 = np.log(dm1)
log_dm1["CT2000.OWN"] = dm1["CT2000.OWN"]
log_dm1["CT2000.DEGREE"] = dm1["CT2000.DEGREE"]
log_dm1["CT2000.VEHICLES"] = dm1["CT2000.VEHICLES"]
log_dm1["CT2000.Geo_FIPS"] = sf2000["CT2000.Geo_FIPS"]
log_dm1["CT2000.Geo_NAME"] = sf2000["CT2000.Geo_NAME"]

# %%
log_dm2 = np.log(dm2)
log_dm2["SFMSA.2000.OWN"] = dm2["SFMSA.2000.OWN"]
log_dm2["SFMSA.2000.DEGREE"] = dm2["SFMSA.2000.DEGREE"]
log_dm2["SFMSA.2000.VEHICLES"] = dm2["SFMSA.2000.VEHICLES"]
log_dm2["SFMSA.2000.Geo_FIPS"] = sf2000msa["SFMSA.2000.Geo_FIPS"]
log_dm2["SFMSA.2000.Geo_NAME"] = sf2000msa["SFMSA.2000.Geo_NAME"]

# %%
pred_dm1 = pd.DataFrame()

for i in range(18, len(log.columns)):
    df = log[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES", log.columns[i]]]
    df.replace(np.Inf, np.nan, inplace = True)
    df.replace(-np.Inf, np.nan, inplace = True)
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    X = df[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES"]]
    Y = df[log.columns[i]]
    X1 = sm.add_constant(X)
    model = linear_model.Lasso(alpha=0.03).fit(X1, Y)
    log_dm1.replace(np.Inf, np.nan, inplace = True)
    log_dm1.replace(-np.Inf, np.nan, inplace = True)
    log_dm1.dropna(inplace = True)
    Xp = log_dm1[["CT2000.SIZE", "CT2000.AVGINCOME", "CT2000.ROOMS", "CT2000.OWN", "CT2000.DEGREE", "CT2000.VEHICLES"]]
    Xp1 = sm.add_constant(Xp)
    pred_dm1[log.columns[i]] = np.array(model.predict(Xp1))
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# ...

# %%
result1 = pred_dm1
for i in pred_dm1.columns:
    result1[i] = np.exp(pred_dm1[i])

# %%
result1["CT2000.Geo_FIPS"] = log_dm1["CT2000.Geo_FIPS"]
result1["CT2000.Geo_NAME"] = log_dm1["CT2000.Geo_NAME"]

# %%
cols = list(result1.columns)
cols = [cols[len(cols) - 2]] + [cols[len(cols) - 1]] + cols[:len(cols) - 2]
result1 = result1[cols]

# %%
result1.to_csv("pred_fmli_sf2000.csv")

# %%
pred_dm2 = pd.DataFrame()
pred_year90 = pd.DataFrame()
pred_year00 = pd.DataFrame()

for i in range(18, len(log.columns)):
    df = log[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES", log.columns[i]]]
    df.replace(np.Inf, np.nan, inplace = True)
    df.replace(-np.Inf, np.nan, inplace = True)
    df.dropna(inplace = True)
    df.reset_index(inplace = True)
    X = df[["HHSIZE", "INCOME", "ROOMS", "OWN", "DEGREE", "VEHICLES"]]
    Y = df[log.columns[i]]
    X1 = sm.add_constant(X)
    model = linear_model.Lasso(alpha=0.03).fit(X1, Y)
    log_dm2.replace(np.Inf, np.nan, inplace = True)
    log_dm2.replace(-np.Inf, np.nan, inplace = True)
    log_dm2.dropna(inplace = True)
    Xp = log_dm2[["SFMSA.2000.SIZE", "SFMSA.2000.AVGINCOME", "SFMSA.2000.ROOMS", "SFMSA.2000.OWN", "SFMSA.2000.DEGREE", "SFMSA.2000.VEHICLES"]]
    Xp1 = sm.add_constant(Xp)
    pred_dm2[log.columns[i]] = np.array(model.predict(Xp1))
    year00["const"] = 1
    year00X = year00[["const", "SFMSA.SIZE", "SFMSA.AVGINCOME", "SFMSA.ROOMS", "SFMSA.OWN", "SFMSA.DEGREE", "SFMSA.VEHICLES"]]
    pred_year00[log.columns[i]] = np.array(model.predict(year00X))
    year90["const"] = 1
    year90X = year90[["const", "SFMSA.SIZE", "SFMSA.AVGINCOME", "SFMSA.ROOMS", "SFMSA.OWN", "SFMSA.DEGREE", "SFMSA.VEHICLES"]]
    pred_year90[log.columns[i]] = np.array(model.predict(year90X))
# Out:
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/winnie/miniconda2/envs/tf/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# ...

# %%
result2 = pred_dm2
for i in pred_dm2.columns:
    result2[i] = np.exp(pred_dm2[i])

# %%
result2["SFMSA.2000.Geo_FIPS"] = log_dm2["SFMSA.2000.Geo_FIPS"]
result2["SFMSA.2000.Geo_NAME"] = log_dm2["SFMSA.2000.Geo_NAME"]

# %%
cols = list(result2.columns)
cols = [cols[len(cols) - 2]] + [cols[len(cols) - 1]] + cols[:len(cols) - 2]
result2 = result2[cols]

# %%
result2.to_csv("pred_fmli_sfmsa2000.csv")

# %%
len(pred_year90.columns)
# Out:
# 42

# %%
for i in pred_year00:
    pred_year00[i] = np.exp(pred_year00[i])
for i in pred_year90:
    pred_year90[i] = np.exp(pred_year90[i])

# %%
pred_year10.columns = pred_year15.columns
pred_year00.columns = pred_year15.columns
pred_year90.columns = pred_year15.columns

# %%
tract5 = pd.concat([pred_year15, pred_year10, pred_year00, pred_year90])

# %%
tract5["SFMSA.Geo_NAME"] = ["SF.Oakland.Hayward.MSA", "SF.Oakland.Hayward.MSA", "SF.Oakland.Hayward.MSA", "SF.Oakland.Hayward.MSA"]
tract5["YEAR"] = [2015, 2010, 2000, 1990]

# %%
cols = list(tract5.columns)
cols = [cols[len(cols) - 2]] + [cols[len(cols) - 1]] + cols[:len(cols) - 2]
tract = tract5[cols]

# %%
tract.to_csv("pred_5county_avg.csv")

# %%
tract
# Out:
#            SFMSA.Geo_NAME  YEAR  TotalExpenditures    TotalFood   FoodAtHome  \
# 0  SF.Oakland.Hayward.MSA  2015       39676.521616  5989.498462  3704.205515
# 0  SF.Oakland.Hayward.MSA  2010       29714.812214  4279.350204  2884.068403
# 0  SF.Oakland.Hayward.MSA  2000       24080.792314  3204.662885  2207.485809
# 0  SF.Oakland.Hayward.MSA  1990       23223.802726  3101.365374  2142.177756
#
#    FoodAwayFromHome  AlcoholicBeverages  Cerealsandbakeryproducts  \
# 0       2199.218003          355.153287                440.279230
# 0       1396.578013          327.526645                403.765303
# 0        811.903288          272.226459               9369.648321
# 0        781.241161          268.845386               9159.937814
#
#    Meatspoultryfishandeggs  Dairyproducts  ...  Entertainment  \
# 0               850.934529     384.614553  ...    1277.521384
# 0               576.813168     317.244863  ...     976.627617
# ...
